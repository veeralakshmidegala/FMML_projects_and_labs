# %% [markdown]
# <a href="https://colab.research.google.com/github/veeralakshmidegala/FMML_projects_and_labs/blob/main/MODULE8_LAB3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 10:34:16--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   119MB/s    in 0.6s
#
# 2024-03-31 10:34:17 (119 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22044   1404.1935v2  We address structured covariance estimation in...  stat
# 3428   1703.07047v2  Recent advances in deep learning for natural i...    cs
# 22281  1511.07294v1  We consider convex-concave saddle point proble...  stat
# 22183  1507.00052v2  We study the Gaussian Process regression model...  stat
# 22131  1501.04080v2  Bayesian optimization is a powerful tool for f...  stat
# ...             ...                                                ...   ...
# 16830  1706.04997v1  We are concerned with the analysis of normativ...    cs
# 12280  1711.02198v1  We consider an online model for recommendation...  stat
# 39939  1708.00940v1  We propose an algorithm that uses energy mini-...    cs
# 7411   1712.06214v1  Objective: Predict patient-specific vitals dee...  stat
# 10324   1204.2588v1  This paper aims at the problem of link pattern...    cs
#
#                                                    title  year  \
# 22044  Tyler's Covariance Matrix Estimator in Ellipti...  2014
# 3428   High-Resolution Breast Cancer Screening with M...  2017
# 22281  Stochastic Parallel Block Coordinate Descent f...  2015
# 22183  Gaussian Process for Noisy Inputs with Orderin...  2015
# 22131       Differentially Private Bayesian Optimization  2015
# ...                                                  ...   ...
# 16830      Extracting Formal Models from Normative Texts  2017
# 12280  Regret Bounds and Regimes of Optimality for Us...  2017
# 39939  An Energy Minimization Approach to 3D Non-Rigi...  2017
# 7411   Predicting Individual Physiologically Acceptab...  2017
# 10324  Probabilistic Latent Tensor Factorization Mode...  2012
#
#                                                 keywords
# 22044  [structured, covariance, estimation, elliptica...
# 3428   [techniques, replacing, convolutional, conside...
# 22281  [separable, structure, functions, efficient, s...
# 22183  [regression, predictive, extremely, challengin...
# 22131  [optimization, parameters, practitioners, clas...
# ...                                                  ...
# 16830  [concerned, normative, documents, obligation, ...
# 12280  [recommendation, recommended, providing, speci...
# 39939  [algorithm, configuration, calculate, correspo...
# 7411   [objective, medically, acceptable, discharge, ...
# 10324  [prediction, collections, connected, predictio...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22044    [structured, covariance, estimation, elliptica...
# 3428     [techniques, replacing, convolutional, conside...
# 22281    [separable, structure, functions, efficient, s...
# 22183    [regression, predictive, extremely, challengin...
# 22131    [optimization, parameters, practitioners, clas...
#                                ...
# 7743     [represented, probability, distribution, conce...
# 4024     [formulation, introduced, algorithm, construct...
# 15437    [characteristics, statistical, networked, meas...
# 26869    [identifying, individual, approaches, spontane...
# 14223    [clustering, dimensional, dimensional, subspac...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8664 words.
# Out of those 4539 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7a014da9-5c32-44d1-90ee-49d0329f4f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a014da9-5c32-44d1-90ee-49d0329f4f26")) {                    Plotly.newPlot(                        "7a014da9-5c32-44d1-90ee-49d0329f4f26",                        [{"x":["estimation","competing","relaxation","efficiently","outperforms","unconstrained","optimization","objective","asymptotically","estimator","covariance","advantages","projection","structured","elliptical","constraints","synthetic","constrained","illustrate","structure","distributions","unfortunately","simulations","performance","developed","resolution","architectures","screening","downsampled","potentially","replacing","convolutional","necessary","additionally","specifically","conclusion","requirements","preprocessing","predictions","techniques","fundamental","detection","differences","consideration","mammography","highlight","difference","investigating","prediction","increases","inadequate","structures","applications","demonstrate","stochastic","empirically","component","significantly","separable","efficiency","theoretically","functions","efficient","principal","flexibility","selection","coordinate","utilizing","simplicity","including","approaches","extremely","particular","parametric","variational","predictive","estimates","consistently","inference","approximation","posterior","monotonically","available","instances","resulting","application","experimental","additional","challenging","computational","uncertainty","regression","practitioners","different","smoothness","assumption","practical","parameters","privately","satisfied","parameter","introduce","differential","sensitive","classifier","observation","statistics","commonplace","leveraging","quantities","differentially","releasing","attractive","convergence","theoretical","guarantees","classifiers","binarized","artificial","attention","classification","individual","feasibility","outstanding","propagation","calculations","therefore","researchers","attracted","irregularly","individuals","improving","experiments","diagnosis","essential","signatures","predictable","healthcare","baselines","observations","measurements","convolution","differentiable","multivariate","architecture","combination","extension","smarandache","especially","preferred","generated","generalized","generalization","management","proportional","redistribution","transactions","intensity","difficult","processing","implementation","algorithms","demonstrated","bilateral","operations","implement","variations","multiscale","denoising","acceleration","simulation","filtering","conference","algorithm","approximating","accelerate","international","exploiting","particularly","identification","derivatives","processes","structural","mechanics","lagrangian","nonparametric","trajectory","simultaneous","uncertain","configuration","observable","knowledge","probabilistic","mechanical","conditioning","configurations","separately","nonlinear","expectation","organizing"],"y":[213,27,17,155,304,26,312,150,13,18,16,87,52,101,1,142,139,70,65,342,115,39,38,912,179,116,131,12,2,50,12,396,65,66,169,19,57,21,79,386,85,349,63,26,2,30,68,13,233,51,7,124,409,563,125,73,94,236,10,154,42,221,420,32,37,154,20,30,27,248,429,58,255,35,45,52,70,33,197,115,33,3,334,86,161,248,350,121,294,295,97,143,17,746,16,72,147,245,0,7,119,328,27,56,134,62,58,1,40,12,1,1,21,97,159,66,113,4,130,190,532,109,26,9,82,12,142,72,32,1,35,101,599,54,74,7,5,13,66,81,50,47,31,25,225,152,72,2,95,6,163,77,109,32,10,2,4,25,167,272,119,631,97,6,70,51,86,15,40,14,77,78,7,834,22,21,16,74,80,116,11,114,65,9,9,13,35,34,28,30,23,363,165,7,8,24,28,58,31,10],"type":"bar"},{"x":["estimation","competing","relaxation","efficie ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4539,), (4539, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Understanding</span> <span style=''>Non</span> <span style=''>optical</span> <span style=''>Remote</span> <span style=''>sensed</span> <span style=''>Images</span> <span style=''>Needs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Challenges</span> <span style=''>and</span> <span style=''>Ways</span> <span style=''>Forward</span> <br/><br/><span style=''>Non</span> <span style=''>optical</span> <span style=''>remote</span> <span style=''>sensed</span> <span style=''>images</span> <span style=''>are</span> <span style=''>going</span> <span style=''>to</span> <span style=''>be</span> <span style=''>used</span> <span style=''>more</span> <span style=''>often</span> <span style=''>in</span> <span style=''>man</span> <span style=''>aging</span> <span style=''>disaster</span> <span style=''>crime</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3666666666666666);'>precision</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>agriculture</span> <span style=''>With</span> <span style=''>more</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>satellites</span> <span style=''>and</span> <span style=''>unmanned</span> <span style=''>air</span> <span style=''>vehicles</span> <span style=''>planning</span> <span style=''>to</span> <span style=''>carry</span> <span style=''>radar</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperspectral</span> <span style=''>image</span> <span style=''>sensors</span> <span style=''>there</span> <span style=''>is</span> <span style=''>going</span> <span style=''>to</span> <span style=''>be</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>abundance</span> <span style=''>of</span> <span style=''>such</span> <span style=''>data</span> <span style=''>in</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>future</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Understanding</span> <span style=''>these</span> <span style=''>data</span> <span style=''>in</span> <span style=''>real</span> <span style=''>time</span> <span style=''>will</span> <span style=''>be</span> <span style=''>crucial</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>attaining</span> <span style=''>some</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>sustain</span> <span style=''>able</span> <span style='background-color:rgba(0, 255, 0, 0.46987951807228917);'>development</span> <span style=''>goals</span> <span style='background-color:rgba(0, 255, 0, 0.36);'>Processing</span> <span style=''>non</span> <span style=''>optical</span> <span style=''>images</span> <span style=''>is</span> <span style=''>in</span> <span style=''>many</span> <span style=''>ways</span> <span style='background-color:rgba(0, 255, 0, 0.325044404973357);'>different</span> <span style=''>from</span> <span style=''>that</span> <span style=''>of</span> <span style=''>optical</span> <span style=''>images</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>recent</span> <span style=''>advances</span> <span style=''>in</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>understanding</span> <span style=''>has</span> <span style=''>been</span> <span style=''>using</span> <span style=''>optical</span> <span style=''>images</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>shall</span> <span style=''>explain</span> <span style=''>the</span> <span style=''>needs</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255,  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Time</span> <span style=''>series</span> <span style=''>Scenario</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Forecasting</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>require</span> <span style=''>the</span> <span style=''>ability</span> <span style=''>to</span> <span style=''>judge</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>of</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Uncertainty</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>specified</span> <span style=''>as</span> <span style=''>point</span> <span style=''>wise</span> <span style=''>error</span> <span style=''>bars</span> <span style=''>around</span> <span style=''>a</span> <span style=''>mean</span> <span style=''>or</span> <span style=''>median</span> <span style=''>forecast</span> <span style=''>Due</span> <span style=''>to</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependencies</span> <span style=''>such</span> <span style=''>a</span> <span style=''>method</span> <span style=''>obscures</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>We</span> <span style=''>would</span> <span style=''>ideally</span> <span style=''>have</span> <span style=''>a</span> <span style=''>way</span> <span style=''>to</span> <span style=''>query</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>entire</span> <span style=''>time</span> <span style=''>series</span> <span style=''>given</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>or</span> <span style=''>at</span> <span style=''>a</span> <span style=''>minimum</span> <span style=''>be</span> <span style=''>able</span> <span style=''>to</span> <span style=''>draw</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>We</span> <span style=''>use</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistically</span> <span style=''>generate</span> <span style=''>an</span> <span style=''>ensemble</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>performs</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>physics</span> <span style=''>based</span> <span style=''>ensemble</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temperature</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>forecasts</span> <span style=''>for</span> <span style=''>Houston</span> <span style=''>We</span> <span style=''>conclude</span> <span style=''>that</span> <span style=''>the</span> <span style=''>method</span> <span style=''>shows</span> <span style=''>promise</span> <span style=''>for</span> <s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.35233160621761656);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Maximization</span> <span style=''>The</span> <span style=''>Case</span> <span style=''>of</span> <span style=''>Coverage</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Functions</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.35233160621761656);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>is</span> <span style=''>at</span> <span style=''>the</span> <span style=''>heart</span> <span style=''>of</span> <span style=''>modern</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>However</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>problems</span> <span style=''>are</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>nature</span> <span style=''>and</span> <span style=''>often</span> <span style=''>involve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objectives</span> <span style=''>We</span> <span style=''>seek</span> <span style=''>to</span> <span style=''>unleash</span> <span style=''>the</span> <span style=''>power</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.35233160621761656);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>namely</span> <span style='background-color:rgba(255, 0, 0, 0.35233160621761656);'>stochastic</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>and</span> <span style=''>its</span> <span style=''>variants</span> <span style=''>to</span> <span style=''>such</span> <span style=''>discrete</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.35233160621761656);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>where</span> <span style=''>one</span> <span style=''>needs</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>submodular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>which</span> <span style=''>is</span> <span style=''>given</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.39805825242718446);'>expectation</span> <span style=''>Our</span> <span style=''>model</span> <span style=''>captures</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>situations</span> <span style=''>where</span> <span style=''>the</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>arises</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>(eg</span> <span style=''>in</span> <span style=''>the</span> <span style=''>case</span> <span style=''>of</span> <span style=''>exemplar</span> <span style=''>based</span> <span style=''>clustering)</span> <span style=''>or</span> <span style=''>is</span> <span style=''>given</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Recovery</span> <span style=''>of</span> <span style=''>Missing</span> <span style=''>Samples</span> <span style=''>Using</span> <span style=''>Sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Approximation</span> <span style=''>via</span> <span style=''>a</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarity</span> <span style=''>Measure</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style=''>missing</span> <span style=''>sample</span> <span style=''>recovery</span> <span style=''>problem</span> <span style=''>using</span> <span style=''>methods</span> <span style=''>based</span> <span style=''>on</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>In</span> <span style=''>this</span> <span style=''>regard</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>used</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>the</span> <span style=''>inverse</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>restoration</span> <span style=''>of</span> <span style=''>missed</span> <span style=''>samples</span> <span style=''>of</span> <span style=''>image</span> <span style=''>signal</span> <span style=''>This</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>also</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inpainting</span> <span style=''>in</span> <span style=''>the</span> <span style=''>context</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>processing</span> <span style=''>and</span> <span style=''>for</span> <span style=''>this</span> <span style=''>purpose</span> <span style=''>we</span> <span style=''>suggest</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style=''>sparse</span> <span style=''>recovery</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>l</span> <span style=''>1</span> <span style=''>norm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>a</span> <span style=''>new</span> <span style=''>fidelity</span> <span style=''>metric</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>metric</span> <span style=''>called</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>SIMilarity</span> <span style=''>(CSIM)</span> <span style=''>index</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>simplified</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>SIMilarity</span> <span style=''>(SSIM)</span> <span style=''>index</span> <span style=''>which</span> <span style=''>is</span> <span style=''>convex</span> <span style=''>and</span> <span style=''>error</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style='backgro ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.07967422096317281)
# 	representation (0.136685552407932)
# 	challenging (0.10410764872521247)
# 	information (0.23796033994334279)
# 	segmentation (0.07011331444759207)
# 	knowledge (0.12854107648725213)
# 	different (0.26416430594900847)
# 	detection (0.12358356940509915)
# 	recognition (0.1274787535410765)
# 	convolutional (0.14022662889518414)
#
# Some Statistics words are:
# 	stochastic (0.132085020242915)
# 	estimation (0.16447368421052633)
# 	variables (0.13714574898785425)
# 	statistical (0.15384615384615385)
# 	theoretical (0.15435222672064777)
# 	algorithm (0.3972672064777328)
# 	dimensional (0.18927125506072875)
# 	distribution (0.19331983805668015)
# 	regression (0.17965587044534412)
# 	inference (0.19888663967611336)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="16ef40e1-ff90-411f-befa-bb011488d7ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16ef40e1-ff90-411f-befa-bb011488d7ec")) {                    Plotly.newPlot(                        "16ef40e1-ff90-411f-befa-bb011488d7ec",                        [{"x":["estimation","competing","relaxation","efficiently","outperforms","unconstrained","optimization","objective","asymptotically","estimator","covariance","advantages","projection","structured","elliptical","constraints","synthetic","constrained","illustrate","structure","distributions","unfortunately","simulations","performance","developed","resolution","architectures","screening","downsampled","potentially","replacing","convolutional","necessary","additionally","specifically","conclusion","requirements","preprocessing","predictions","techniques","fundamental","detection","differences","consideration","mammography","highlight","difference","investigating","prediction","increases","inadequate","structures","applications","demonstrate","stochastic","empirically","component","significantly","separable","efficiency","theoretically","functions","efficient","principal","flexibility","selection","coordinate","utilizing","simplicity","including","approaches","extremely","particular","parametric","variational","predictive","estimates","consistently","inference","approximation","posterior","monotonically","available","instances","resulting","application","experimental","additional","challenging","computational","uncertainty","regression","practitioners","different","smoothness","assumption","practical","parameters","privately","satisfied","parameter","introduce","differential","sensitive","classifier","observation","statistics","commonplace","leveraging","quantities","differentially","releasing","attractive","convergence","theoretical","guarantees","classifiers","binarized","artificial","attention","classification","individual","feasibility","outstanding","propagation","calculations","therefore","researchers","attracted","irregularly","individuals","improving","experiments","diagnosis","essential","signatures","predictable","healthcare","baselines","observations","measurements","convolution","differentiable","multivariate","architecture","combination","extension","smarandache","especially","preferred","generated","generalized","generalization","management","proportional","redistribution","transactions","intensity","difficult","processing","implementation","algorithms","demonstrated","bilateral","operations","implement","variations","multiscale","denoising","acceleration","simulation","filtering","conference","algorithm","approximating","accelerate","international","exploiting","particularly","identification","derivatives","processes","structural","mechanics","lagrangian","nonparametric","trajectory","simultaneous","uncertain","configuration","observable","knowledge","probabilistic","mechanical","conditioning","configurations","separately","nonlinear","expectation","organizing","clustering","maximisation","frequentist","similarities","dependent","reproducing","kernelised","arbitrary","contextual","cumulative","described","collected","behaviors","respective","increasingly","information","dirichlet","interested","conjunction","characterize","associated","conditions","situation","hierarchical","destinations","orientation","quantized","opportunities","starcraft","collection","technical","platforms","container","convenient","installed","developement","supporting","importance","evolution","previously","understand","spatially","framework","modelling","background","complicated","requisite","recordings","physiological","empirical","simulated","electrical","assimilate","spatiotemporal","epil ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	privately
# 	epileptic
# 	irradiance
# 	mandatory
# 	asymptotics
# 	isometrically
# 	nonparametrics
# 	shrinkage
# 	martingale
# 	integrator
# 	reparametrizations
# 	reparametrization
# 	consolidation
# 	affinities
# 	portfolios
# 	permutations
# 	tibshirani
# 	nonnegativity
# 	sandwiched
# 	certificate
# Some words which never appear in Statistics papers:
# 	downsampled
# 	mammography
# 	smarandache
# 	redistribution
# 	maximisation
# 	kernelised
# 	starcraft
# 	container
# 	installed
# 	developement
# 	functioning
# 	dempstershafer
# 	actuation
# 	dependable
# 	photorealistic
# 	unlimited
# 	hematoxylin
# 	histopathology
# 	specimens
# 	epithelial

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0507337014552002e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7675
